# %%
a = 3 
print(a * 3)

b = 5
print(b * 5)


text = '20241014sunny'

year = '2024'
month = '10' 
day = '14' 
weather = 'sunny'


print(text[0:4])

print(text[4:6])

print(text[6:8])

print(text[8:13])


kor = 80
eng = 75
math = 55

total = kor + eng + math

average = (kor + eng + math) / 3

print(average)


#[1,3,5,4,2] 리스트를 [5,4,3,2,1]로 만들어보자 

number = [1,3,5,4,2]
number.sort()
print(number)

number.reverse()
print(number)


#홍길동 씨의 주민등록번호는 881120-1068234이다. 홍길동 씨의 주민등록번호를 연 월 일(yyyymmdd)부분과 그 뒤의 숫자 부분으로 나누어 출력해보자. 

number = "881120-1068234"

print("19"+ number[:6])
print(number[7:])


#딕셔너리 a에서 'B'에 해당하는 값을 추출해보자. 

a={'A': 90,'B': 80,'C': 70}

result = a['B']
print(result)
# Out:
# 9
# 25
# 2024
# 10
# 14
# sunny
# 70.0
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]
# 19881120
# 1068234
# 80
