# %% [markdown]
# 숫자형은 어떻게 만들고 사용할까?
#
# 정수형
# 정수형(integer)은 말 그대로 정수를 뜻하는 자료형이다. 다음은 양의 정수, 음의 정수, 숫자 0을 변수 a에 대입하는 예이다.

# %% [markdown]
# a = 123
#
# a = -178
#
# a = 0

# %% [markdown]
# 실수형
# 실수형(floating-point)은 소수점이 포함된 숫자를 말한다. 다음은 실수를 변수 a에 대입하는 예이다.

# %% [markdown]
# a = 1.2
#
# a = -3.45

# %% [markdown]
# 파이썬에서는 4.24e10 또는 4.24E10처럼 지수 표현 방식도 사용할 수 있다(e와 E 둘 중 어느 것을 사용해도 된다).

# %% [markdown]
# a = 4.24E10
#
# a = 4.24e-10

# %% [markdown]
# 여기서 4.24E10은
# , 4.24e-10은 을 의미한다.

# %% [markdown]
# 8진수와 16진수

# %% [markdown]
# 8진수(octal)는 0o 또는 0O(숫자 0 + 알파벳 소문자 o 또는 대문자 O)로 시작한다.

# %% [markdown]
# a = 0o177
#
# print(a)
#
# 127
