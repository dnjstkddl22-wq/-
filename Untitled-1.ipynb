# %%
print('안녕하세요.')

a = 10
print(a)

a = 20
print(a)

a = 10
b = 10.123

print(a)
print(b)

print(type (a))
print(type (b))

a = 10
b = 5

result = a + b
print(result)
print(a + b)

result = a - b
print(result)

result = a * b
print(result)


# 주석 

"""

여기에다가 
무언가를 적어도 
에러가 발생하지 않습니다. 

"""

a = 3 
print(a * 3)

b = 5
print(b * 5)


text = '20241014sunny'

year = '2024'
month = '10' 
day = '14' 
weather = 'sunny'


print(text[0:4])

print(text[4:6])

print(text[6:8])

print(text[8:13])
# Out:
# 안녕하세요.
# 10
# 20
# 10
# 10.123
# <class 'int'>
# <class 'float'>
# 15
# 15
# 5
# 50
# 9
# 25
# 2024
# 10
# 14
# sunny
